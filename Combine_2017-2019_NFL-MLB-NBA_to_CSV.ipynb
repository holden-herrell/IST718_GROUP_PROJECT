# %%
#Import Required Packages
import pandas as pd
import numpy as np

# %%
#Import NFL Schedule Data
NFL2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NFL%20DATA/NFL2017.csv'
NFL2017=pd.read_csv(NFL2017url, engine='python', error_bad_lines=False)
NFL2017df=pd.DataFrame(NFL2017)
print(NFL2017df)

NFL2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NFL%20DATA/NFL2018.csv'
NFL2018=pd.read_csv(NFL2018url, engine='python', error_bad_lines=False)
NFL2018df=pd.DataFrame(NFL2018)
print(NFL2018df)

NFL2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NFL%20DATA/NFL2019.csv'
NFL2019=pd.read_csv(NFL2019url, engine='python', error_bad_lines=False)
NFL2019df=pd.DataFrame(NFL2019)
print(NFL2019df)
# Out:
#           Week  Day          Date    Time            Winner/tie Unnamed: 5  \
# 0            1  Thu   September 7  8:30PM    Kansas City Chiefs          @
# 1            1  Sun  September 10  1:00PM       Oakland Raiders          @
# 2            1  Sun  September 10  1:00PM       Atlanta Falcons          @
# 3            1  Sun  September 10  1:00PM         Buffalo Bills        NaN
# 4            1  Sun  September 10  1:00PM   Pittsburgh Steelers          @
# ..         ...  ...           ...     ...                   ...        ...
# 263   Division  Sun    January 14  1:05PM  Jacksonville Jaguars          @
# 264   Division  Sun    January 14  4:40PM     Minnesota Vikings        NaN
# 265  ConfChamp  Sun    January 21  3:05PM  New England Patriots        NaN
# 266  ConfChamp  Sun    January 21  6:40PM   Philadelphia Eagles        NaN
# 267  SuperBowl  Sun    February 4  6:30PM   Philadelphia Eagles          N
#
# ...

# %%
#Add Years to Each Season
NFL2017df['Year']=2017
print(NFL2017df)
NFL2018df['Year']=2018
print(NFL2018df)
NFL2019df['Year']=2019
print(NFL2019df)
# Out:
#           Week  Day          Date    Time            Winner/tie Unnamed: 5  \
# 0            1  Thu   September 7  8:30PM    Kansas City Chiefs          @
# 1            1  Sun  September 10  1:00PM       Oakland Raiders          @
# 2            1  Sun  September 10  1:00PM       Atlanta Falcons          @
# 3            1  Sun  September 10  1:00PM         Buffalo Bills        NaN
# 4            1  Sun  September 10  1:00PM   Pittsburgh Steelers          @
# ..         ...  ...           ...     ...                   ...        ...
# 263   Division  Sun    January 14  1:05PM  Jacksonville Jaguars          @
# 264   Division  Sun    January 14  4:40PM     Minnesota Vikings        NaN
# 265  ConfChamp  Sun    January 21  3:05PM  New England Patriots        NaN
# 266  ConfChamp  Sun    January 21  6:40PM   Philadelphia Eagles        NaN
# 267  SuperBowl  Sun    February 4  6:30PM   Philadelphia Eagles          N
#
# ...

# %%
#Adjust year for playoff months in next year
NFL2017df.loc[NFL2017df['Date'].str.contains('January'), ['Year']] = 2018
NFL2017df.loc[NFL2017df['Date'].str.contains('February'), ['Year']] = 2018
print(NFL2017df)
NFL2018df.loc[NFL2018df['Date'].str.contains('January'), ['Year']] = 2019
NFL2018df.loc[NFL2018df['Date'].str.contains('February'), ['Year']] = 2019
print(NFL2018df)
NFL2019df.loc[NFL2019df['Date'].str.contains('January'), ['Year']] =2020
NFL2019df.loc[NFL2019df['Date'].str.contains('February'), ['Year']] = 2020
print(NFL2019df)
# Out:
#           Week  Day          Date    Time            Winner/tie Unnamed: 5  \
# 0            1  Thu   September 7  8:30PM    Kansas City Chiefs          @
# 1            1  Sun  September 10  1:00PM       Oakland Raiders          @
# 2            1  Sun  September 10  1:00PM       Atlanta Falcons          @
# 3            1  Sun  September 10  1:00PM         Buffalo Bills        NaN
# 4            1  Sun  September 10  1:00PM   Pittsburgh Steelers          @
# ..         ...  ...           ...     ...                   ...        ...
# 263   Division  Sun    January 14  1:05PM  Jacksonville Jaguars          @
# 264   Division  Sun    January 14  4:40PM     Minnesota Vikings        NaN
# 265  ConfChamp  Sun    January 21  3:05PM  New England Patriots        NaN
# 266  ConfChamp  Sun    January 21  6:40PM   Philadelphia Eagles        NaN
# 267  SuperBowl  Sun    February 4  6:30PM   Philadelphia Eagles          N
#
# ...

# %%
#Combine all NFL Seasons
NFLSchedule=NFL2017df.append(NFL2018df, sort=False, ignore_index=True)
NFLSchedule=NFLSchedule.append(NFL2019df, sort=False, ignore_index=True)
#pd.options.display.max_rows = 999
print(NFLSchedule)
# Out:
#           Week  Day          Date    Time           Winner/tie Unnamed: 5  \
# 0            1  Thu   September 7  8:30PM   Kansas City Chiefs          @
# 1            1  Sun  September 10  1:00PM      Oakland Raiders          @
# 2            1  Sun  September 10  1:00PM      Atlanta Falcons          @
# 3            1  Sun  September 10  1:00PM        Buffalo Bills        NaN
# 4            1  Sun  September 10  1:00PM  Pittsburgh Steelers          @
# ..         ...  ...           ...     ...                  ...        ...
# 799   Division  Sun    January 12  3:05PM   Kansas City Chiefs        NaN
# 800   Division  Sun    January 12  6:40PM    Green Bay Packers        NaN
# 801  ConfChamp  Sun    January 19  3:05PM   Kansas City Chiefs        NaN
# 802  ConfChamp  Sun    January 19  6:40PM  San Francisco 49ers        NaN
# 803  SuperBowl  Sun    February 2  6:30PM   Kansas City Chiefs          N
#
#                 Loser/tie Unnamed: 7  PtsW  PtsL   YdsW  TOW   YdsL  TOL  Year
# ...

# %%
#Rename unnamed columns
NFLSchedule.rename(columns={"Unnamed: 5":"At","Unnamed: 7":"BoxScore"},inplace=True)
print(NFLSchedule)
# Out:
#           Week  Day          Date    Time           Winner/tie   At  \
# 0            1  Thu   September 7  8:30PM   Kansas City Chiefs    @
# 1            1  Sun  September 10  1:00PM      Oakland Raiders    @
# 2            1  Sun  September 10  1:00PM      Atlanta Falcons    @
# 3            1  Sun  September 10  1:00PM        Buffalo Bills  NaN
# 4            1  Sun  September 10  1:00PM  Pittsburgh Steelers    @
# ..         ...  ...           ...     ...                  ...  ...
# 799   Division  Sun    January 12  3:05PM   Kansas City Chiefs  NaN
# 800   Division  Sun    January 12  6:40PM    Green Bay Packers  NaN
# 801  ConfChamp  Sun    January 19  3:05PM   Kansas City Chiefs  NaN
# 802  ConfChamp  Sun    January 19  6:40PM  San Francisco 49ers  NaN
# 803  SuperBowl  Sun    February 2  6:30PM   Kansas City Chiefs    N
#
#                 Loser/tie  BoxScore  PtsW  PtsL   YdsW  TOW   YdsL  TOL  Year
# ...

# %%
#Add HomeTeam
NFLSchedule['HomeTeam']=NFLSchedule['Winner/tie']

# %%
#Fix HomeTeam to account for @
NFLSchedule.loc[NFLSchedule['At']=='@', ['HomeTeam']] = NFLSchedule['Loser/tie']
print(NFLSchedule)
# Out:
#           Week  Day          Date    Time           Winner/tie   At  \
# 0            1  Thu   September 7  8:30PM   Kansas City Chiefs    @
# 1            1  Sun  September 10  1:00PM      Oakland Raiders    @
# 2            1  Sun  September 10  1:00PM      Atlanta Falcons    @
# 3            1  Sun  September 10  1:00PM        Buffalo Bills  NaN
# 4            1  Sun  September 10  1:00PM  Pittsburgh Steelers    @
# ..         ...  ...           ...     ...                  ...  ...
# 799   Division  Sun    January 12  3:05PM   Kansas City Chiefs  NaN
# 800   Division  Sun    January 12  6:40PM    Green Bay Packers  NaN
# 801  ConfChamp  Sun    January 19  3:05PM   Kansas City Chiefs  NaN
# 802  ConfChamp  Sun    January 19  6:40PM  San Francisco 49ers  NaN
# 803  SuperBowl  Sun    February 2  6:30PM   Kansas City Chiefs    N
#
#                 Loser/tie  BoxScore  PtsW  PtsL   YdsW  TOW   YdsL  TOL  Year  \
# ...

# %%
#Subset for cities in this study
NFL= NFLSchedule[NFLSchedule['HomeTeam'].isin(['Atlanta Falcons','Dallas Cowboys','Houston Texans','Miami Dolphins'])]
print(NFL)
# Out:
#          Week  Day          Date    Time            Winner/tie   At  \
# 8           1  Sun  September 10  1:00PM  Jacksonville Jaguars    @
# 12          1  Sun  September 10  8:30PM        Dallas Cowboys  NaN
# 29          2  Sun  September 17  8:30PM       Atlanta Falcons  NaN
# 48          4  Sun     October 1  9:30AM    New Orleans Saints    @
# 50          4  Sun     October 1  1:00PM        Houston Texans  NaN
# ..        ...  ...           ...     ...                   ...  ...
# 763        16  Sun   December 22  1:00PM       Atlanta Falcons  NaN
# 767        16  Sun   December 22  1:00PM        Miami Dolphins  NaN
# 785        17  Sun   December 29  4:25PM      Tennessee Titans    @
# 788        17  Sun   December 29  4:25PM        Dallas Cowboys  NaN
# 793  WildCard  Sat     January 4  4:35PM        Houston Texans  NaN
#
#                 Loser/tie  BoxScore  PtsW  PtsL   YdsW  TOW   YdsL  TOL  Year  \
# ...

# %%
#Drop Unneeded columns
NFL=NFL.drop(columns=['Week','Winner/tie','At','Loser/tie','BoxScore','PtsW','PtsL','YdsW','TOW','YdsL','TOL'])
print(NFL)
# Out:
#      Day          Date    Time  Year         HomeTeam
# 8    Sun  September 10  1:00PM  2017   Houston Texans
# 12   Sun  September 10  8:30PM  2017   Dallas Cowboys
# 29   Sun  September 17  8:30PM  2017  Atlanta Falcons
# 48   Sun     October 1  9:30AM  2017   Miami Dolphins
# 50   Sun     October 1  1:00PM  2017   Houston Texans
# ..   ...           ...     ...   ...              ...
# 763  Sun   December 22  1:00PM  2019  Atlanta Falcons
# 767  Sun   December 22  1:00PM  2019   Miami Dolphins
# 785  Sun   December 29  4:25PM  2019   Houston Texans
# 788  Sun   December 29  4:25PM  2019   Dallas Cowboys
# 793  Sat     January 4  4:35PM  2020   Houston Texans
#
# [99 rows x 5 columns]

# %%
#NFL.to_csv('NFL.csv', index=False)

# %%
#Import MLB Schedule Data
#Atlanta (Braves)
ATL2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/MLB%20DATA/ATL_MLB2017.csv'
ATL2017=pd.read_csv(ATL2017url, engine='python', error_bad_lines=False)
ATL2017df=pd.DataFrame(ATL2017)
ATL2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/MLB%20DATA/ATL_MLB2018.csv'
ATL2018=pd.read_csv(ATL2018url, engine='python', error_bad_lines=False)
ATL2018df=pd.DataFrame(ATL2018)
ATL2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/MLB%20DATA/ATL_MLB2019.csv'
ATL2019=pd.read_csv(ATL2019url, engine='python', error_bad_lines=False)
ATL2019df=pd.DataFrame(ATL2019)
#Dallas (Texas Rangers)
DAL2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/MLB%20DATA/DAL_MLB2017.csv'
DAL2017=pd.read_csv(DAL2017url, engine='python', error_bad_lines=False)
DAL2017df=pd.DataFrame(DAL2017)
DAL2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/MLB%20DATA/DAL_MLB2019.csv'
DAL2018=pd.read_csv(DAL2018url, engine='python', error_bad_lines=False)
DAL2018df=pd.DataFrame(DAL2018)
DAL2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/MLB%20DATA/DAL_MLB2019.csv'
DAL2019=pd.read_csv(DAL2019url, engine='python', error_bad_lines=False)
DAL2019df=pd.DataFrame(DAL2019)
#Houston (Astros)
HOU2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/MLB%20DATA/HOU_MLB2017.csv'
HOU2017=pd.read_csv(HOU2017url, engine='python', error_bad_lines=False)
HOU2017df=pd.DataFrame(HOU2017)
HOU2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/MLB%20DATA/HOU_MLB2018.csv'
HOU2018=pd.read_csv(HOU2018url, engine='python', error_bad_lines=False)
HOU2018df=pd.DataFrame(HOU2018)
HOU2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/MLB%20DATA/HOU_MLB2019.csv'
HOU2019=pd.read_csv(HOU2019url, engine='python', error_bad_lines=False)
HOU2019df=pd.DataFrame(HOU2019)
#Miami (Marlins)
MIA2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/MLB%20DATA/MIA_MLB2017.csv'
MIA2017=pd.read_csv(MIA2017url, engine='python', error_bad_lines=False)
MIA2017df=pd.DataFrame(MIA2017)
MIA2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/MLB%20DATA/MIA_MLB2018.csv'
MIA2018=pd.read_csv(MIA2018url, engine='python', error_bad_lines=False)
MIA2018df=pd.DataFrame(MIA2018)
MIA2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/MLB%20DATA/MIA_MLB2019.csv'
MIA2019=pd.read_csv(MIA2019url, engine='python', error_bad_lines=False)
MIA2019df=pd.DataFrame(MIA2019)
print(MIA2019df)
# Out:
#      Gm#              Date Unnamed: 2   Tm Unnamed: 4  Opp   W/L  R  RA   Inn  \
# 0      1   Thursday Mar 28   boxscore  MIA        NaN  COL     L  3   6   NaN
# 1      2     Friday Mar 29   boxscore  MIA        NaN  COL     L  1   6   NaN
# 2      3   Saturday Mar 30   boxscore  MIA        NaN  COL     W  7   3   NaN
# 3      4     Sunday Mar 31   boxscore  MIA        NaN  COL     W  3   0   NaN
# 4      5      Monday Apr 1   boxscore  MIA        NaN  NYM     L  3   7   NaN
# ..   ...               ...        ...  ...        ...  ...   ... ..  ..   ...
# 157  158  Wednesday Sep 25   boxscore  MIA          @  NYM     L  3  10   NaN
# 158  159   Thursday Sep 26   boxscore  MIA          @  NYM     W  4   2   NaN
# 159  160     Friday Sep 27   boxscore  MIA          @  PHI  L-wo  4   5  15.0
# 160  161   Saturday Sep 28   boxscore  MIA          @  PHI     L  3   9   NaN
# 161  162     Sunday Sep 29   boxscore  MIA          @  PHI     W  4   3   NaN
#
# ...

# %%
#Add Years to MLB Data
ATL2017df['Year']=2017
DAL2017df['Year']=2017
HOU2017df['Year']=2017
MIA2017df['Year']=2017

ATL2018df['Year']=2018
DAL2018df['Year']=2018
HOU2018df['Year']=2018
MIA2018df['Year']=2018

ATL2019df['Year']=2019
DAL2019df['Year']=2019
HOU2019df['Year']=2019
MIA2019df['Year']=2019

# %%
pd.options.display.max_rows = 162
print(MIA2019)
# Out:
#      Gm#              Date Unnamed: 2   Tm Unnamed: 4  Opp   W/L   R  RA  \
# 0      1   Thursday Mar 28   boxscore  MIA        NaN  COL     L   3   6
# 1      2     Friday Mar 29   boxscore  MIA        NaN  COL     L   1   6
# 2      3   Saturday Mar 30   boxscore  MIA        NaN  COL     W   7   3
# 3      4     Sunday Mar 31   boxscore  MIA        NaN  COL     W   3   0
# 4      5      Monday Apr 1   boxscore  MIA        NaN  NYM     L   3   7
# 5      6     Tuesday Apr 2   boxscore  MIA        NaN  NYM     L   5   6
# 6      7   Wednesday Apr 3   boxscore  MIA        NaN  NYM     L   4   6
# 7      8      Friday Apr 5   boxscore  MIA          @  ATL     L   0   4
# 8      9    Saturday Apr 6   boxscore  MIA          @  ATL     W   4   2
# 9     10      Sunday Apr 7   boxscore  MIA          @  ATL  L-wo   3   4
# 10    11     Tuesday Apr 9   boxscore  MIA          @  CIN     L   0  14
# 11    12  Wednesday Apr 10   boxscore  MIA          @  CIN     L   1   2
# ...

# %%
#Combine MLB Schedule Data
MLBSchedule=ATL2017df.append(ATL2018df, sort=False, ignore_index=True)
MLBSchedule=MLBSchedule.append(ATL2019df, sort=False, ignore_index=True)
MLBSchedule=MLBSchedule.append(DAL2017df, sort=False, ignore_index=True)
MLBSchedule=MLBSchedule.append(DAL2018df, sort=False, ignore_index=True)
MLBSchedule=MLBSchedule.append(DAL2019df, sort=False, ignore_index=True)
MLBSchedule=MLBSchedule.append(HOU2017df, sort=False, ignore_index=True)
MLBSchedule=MLBSchedule.append(HOU2018df, sort=False, ignore_index=True)
MLBSchedule=MLBSchedule.append(HOU2019df, sort=False, ignore_index=True)
MLBSchedule=MLBSchedule.append(MIA2017df, sort=False, ignore_index=True)
MLBSchedule=MLBSchedule.append(MIA2018df, sort=False, ignore_index=True)
MLBSchedule=MLBSchedule.append(MIA2019df, sort=False, ignore_index=True)
#pd.options.display.max_rows = 9999
print(MLBSchedule)
# Out:
#       Gm#                  Date Unnamed: 2   Tm Unnamed: 4  Opp   W/L   R  RA  \
# 0       1          Monday Apr 3   boxscore  ATL          @  NYM     L   0   6
# 1       2       Wednesday Apr 5   boxscore  ATL          @  NYM     W   3   1
# 2       3        Thursday Apr 6   boxscore  ATL          @  NYM     L   2   6
# 3       4          Friday Apr 7   boxscore  ATL          @  PIT     L   4   5
# 4       5        Saturday Apr 8   boxscore  ATL          @  PIT     L   4   6
# 5       6          Sunday Apr 9   boxscore  ATL          @  PIT  L-wo   5   6
# 6       7        Tuesday Apr 11   boxscore  ATL          @  MIA     L   4   8
# 7       8      Wednesday Apr 12   boxscore  ATL          @  MIA     W   5   4
# 8       9         Friday Apr 14   boxscore  ATL        NaN  SDP     W   5   2
# 9      10       Saturday Apr 15   boxscore  ATL        NaN  SDP     W   4   2
# 10     11         Sunday Apr 16   boxscore  ATL        NaN  SDP     W   9   2
# ...

# %%
#Rename unnamed columns
MLBSchedule.rename(columns={"Unnamed: 2":"BoxScore","Unnamed: 4":"At"},inplace=True)
print(MLBSchedule)
# Out:
#       Gm#                  Date  BoxScore   Tm   At  Opp   W/L   R  RA   Inn  \
# 0       1          Monday Apr 3  boxscore  ATL    @  NYM     L   0   6   NaN
# 1       2       Wednesday Apr 5  boxscore  ATL    @  NYM     W   3   1  12.0
# 2       3        Thursday Apr 6  boxscore  ATL    @  NYM     L   2   6   NaN
# 3       4          Friday Apr 7  boxscore  ATL    @  PIT     L   4   5   NaN
# 4       5        Saturday Apr 8  boxscore  ATL    @  PIT     L   4   6   NaN
# 5       6          Sunday Apr 9  boxscore  ATL    @  PIT  L-wo   5   6  10.0
# 6       7        Tuesday Apr 11  boxscore  ATL    @  MIA     L   4   8   NaN
# 7       8      Wednesday Apr 12  boxscore  ATL    @  MIA     W   5   4   NaN
# 8       9         Friday Apr 14  boxscore  ATL  NaN  SDP     W   5   2   NaN
# 9      10       Saturday Apr 15  boxscore  ATL  NaN  SDP     W   4   2   NaN
# 10     11         Sunday Apr 16  boxscore  ATL  NaN  SDP     W   9   2   NaN
# ...

# %%
#Add HomeTeam
MLBSchedule['HomeTeam']=MLBSchedule['Tm']

# %%
#Fix HomeTeam to account for @
MLBSchedule.loc[MLBSchedule['At']=='@', ['HomeTeam']] = MLBSchedule['Opp']
print(MLBSchedule)
# Out:
#       Gm#                  Date  BoxScore   Tm   At  Opp   W/L   R  RA   Inn  \
# 0       1          Monday Apr 3  boxscore  ATL    @  NYM     L   0   6   NaN
# 1       2       Wednesday Apr 5  boxscore  ATL    @  NYM     W   3   1  12.0
# 2       3        Thursday Apr 6  boxscore  ATL    @  NYM     L   2   6   NaN
# 3       4          Friday Apr 7  boxscore  ATL    @  PIT     L   4   5   NaN
# 4       5        Saturday Apr 8  boxscore  ATL    @  PIT     L   4   6   NaN
# 5       6          Sunday Apr 9  boxscore  ATL    @  PIT  L-wo   5   6  10.0
# 6       7        Tuesday Apr 11  boxscore  ATL    @  MIA     L   4   8   NaN
# 7       8      Wednesday Apr 12  boxscore  ATL    @  MIA     W   5   4   NaN
# 8       9         Friday Apr 14  boxscore  ATL  NaN  SDP     W   5   2   NaN
# 9      10       Saturday Apr 15  boxscore  ATL  NaN  SDP     W   4   2   NaN
# 10     11         Sunday Apr 16  boxscore  ATL  NaN  SDP     W   9   2   NaN
# ...

# %%
#Subset for cities in this study
MLB= MLBSchedule[MLBSchedule['HomeTeam'].isin(['ATL','TEX','HOU','MIA'])]
print(MLB)
# Out:
#       Gm#                 Date  BoxScore   Tm   At  Opp   W/L   R  RA   Inn  \
# 6       7       Tuesday Apr 11  boxscore  ATL    @  MIA     L   4   8   NaN
# 7       8     Wednesday Apr 12  boxscore  ATL    @  MIA     W   5   4   NaN
# 8       9        Friday Apr 14  boxscore  ATL  NaN  SDP     W   5   2   NaN
# 9      10      Saturday Apr 15  boxscore  ATL  NaN  SDP     W   4   2   NaN
# 10     11        Sunday Apr 16  boxscore  ATL  NaN  SDP     W   9   2   NaN
# 11     12        Monday Apr 17  boxscore  ATL  NaN  SDP  W-wo   5   4   NaN
# 12     13       Tuesday Apr 18  boxscore  ATL  NaN  WSN     L   1   3   NaN
# 13     14     Wednesday Apr 19  boxscore  ATL  NaN  WSN     L   4  14   NaN
# 14     15      Thursday Apr 20  boxscore  ATL  NaN  WSN     L   2   3   NaN
# 23     24         Monday May 1  boxscore  ATL  NaN  NYM     L   5   7   NaN
# 24     25        Tuesday May 2  boxscore  ATL  NaN  NYM     W   9   7   NaN
# ...

# %%
#Drop Unneeded columns
MLB=MLB.drop(columns=['Gm#','BoxScore','Tm','At','Opp','W/L','R','RA','Inn',
                      'Win','Loss','Save','Streak','Orig. Scheduled','W-L','Rank','GB'])
print(MLB)
# Out:
#                      Date  Time D/N  Attendance  Year HomeTeam
# 6          Tuesday Apr 11  2:54   N     36519.0  2017      MIA
# 7        Wednesday Apr 12  2:51   N     16808.0  2017      MIA
# 8           Friday Apr 14  2:57   N     41149.0  2017      ATL
# 9         Saturday Apr 15  2:20   N     41149.0  2017      ATL
# 10          Sunday Apr 16  2:46   D     37147.0  2017      ATL
# 11          Monday Apr 17  2:48   N     24516.0  2017      ATL
# 12         Tuesday Apr 18  3:09   N     21834.0  2017      ATL
# 13       Wednesday Apr 19  3:32   N     22101.0  2017      ATL
# 14        Thursday Apr 20  2:41   N     27498.0  2017      ATL
# 23           Monday May 1  3:00   N     21668.0  2017      ATL
# 24          Tuesday May 2  2:55   N     21359.0  2017      ATL
# 25        Wednesday May 3  3:34   N     22656.0  2017      ATL
# 26           Friday May 5  3:13   N     34465.0  2017      ATL
# 27         Saturday May 6  2:59   N     40706.0  2017      ATL
# ...

# %%
#MLB.to_csv('MLB.csv', index=False)

# %%
#Import NBA Schedule Data
#2017
NBA_01_2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_01_2017.csv'
NBA_01_2017=pd.read_csv(NBA_01_2017url, engine='python', error_bad_lines=False)
NBA_01_2017df=pd.DataFrame(NBA_01_2017)
NBA_02_2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_02_2017.csv'
NBA_02_2017=pd.read_csv(NBA_02_2017url, engine='python', error_bad_lines=False)
NBA_02_2017df=pd.DataFrame(NBA_02_2017)
NBA_03_2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_03_2017.csv'
NBA_03_2017=pd.read_csv(NBA_03_2017url, engine='python', error_bad_lines=False)
NBA_03_2017df=pd.DataFrame(NBA_03_2017)
NBA_04_2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_04_2017.csv'
NBA_04_2017=pd.read_csv(NBA_04_2017url, engine='python', error_bad_lines=False)
NBA_04_2017df=pd.DataFrame(NBA_04_2017)
NBA_05_2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_05_2017.csv'
NBA_05_2017=pd.read_csv(NBA_05_2017url, engine='python', error_bad_lines=False)
NBA_05_2017df=pd.DataFrame(NBA_05_2017)
NBA_06_2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_06_2017.csv'
NBA_06_2017=pd.read_csv(NBA_06_2017url, engine='python', error_bad_lines=False)
NBA_06_2017df=pd.DataFrame(NBA_06_2017)
NBA_10_2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_10_2017.csv'
NBA_10_2017=pd.read_csv(NBA_10_2017url, engine='python', error_bad_lines=False)
NBA_10_2017df=pd.DataFrame(NBA_10_2017)
NBA_11_2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_11_2017.csv'
NBA_11_2017=pd.read_csv(NBA_11_2017url, engine='python', error_bad_lines=False)
NBA_11_2017df=pd.DataFrame(NBA_11_2017)
NBA_12_2017url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_12_2017.csv'
NBA_12_2017=pd.read_csv(NBA_12_2017url, engine='python', error_bad_lines=False)
NBA_12_2017df=pd.DataFrame(NBA_12_2017)
#2018
NBA_01_2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_01_2018.csv'
NBA_01_2018=pd.read_csv(NBA_01_2018url, engine='python', error_bad_lines=False)
NBA_01_2018df=pd.DataFrame(NBA_01_2018)
NBA_02_2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_02_2018.csv'
NBA_02_2018=pd.read_csv(NBA_02_2018url, engine='python', error_bad_lines=False)
NBA_02_2018df=pd.DataFrame(NBA_02_2018)
NBA_03_2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_03_2018.csv'
NBA_03_2018=pd.read_csv(NBA_03_2018url, engine='python', error_bad_lines=False)
NBA_03_2018df=pd.DataFrame(NBA_03_2018)
NBA_04_2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_04_2018.csv'
NBA_04_2018=pd.read_csv(NBA_04_2018url, engine='python', error_bad_lines=False)
NBA_04_2018df=pd.DataFrame(NBA_04_2018)
NBA_05_2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_05_2018.csv'
NBA_05_2018=pd.read_csv(NBA_05_2018url, engine='python', error_bad_lines=False)
NBA_05_2018df=pd.DataFrame(NBA_05_2018)
NBA_06_2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_06_2018.csv'
NBA_06_2018=pd.read_csv(NBA_06_2018url, engine='python', error_bad_lines=False)
NBA_06_2018df=pd.DataFrame(NBA_06_2018)
NBA_10_2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_10_2018.csv'
NBA_10_2018=pd.read_csv(NBA_10_2018url, engine='python', error_bad_lines=False)
NBA_10_2018df=pd.DataFrame(NBA_10_2018)
NBA_11_2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_11_2018.csv'
NBA_11_2018=pd.read_csv(NBA_11_2018url, engine='python', error_bad_lines=False)
NBA_11_2018df=pd.DataFrame(NBA_11_2018)
NBA_12_2018url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_12_2018.csv'
NBA_12_2018=pd.read_csv(NBA_12_2018url, engine='python', error_bad_lines=False)
NBA_12_2018df=pd.DataFrame(NBA_12_2018)
#2019
NBA_01_2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_01_2019.csv'
NBA_01_2019=pd.read_csv(NBA_01_2019url, engine='python', error_bad_lines=False)
NBA_01_2019df=pd.DataFrame(NBA_01_2019)
NBA_02_2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_02_2019.csv'
NBA_02_2019=pd.read_csv(NBA_02_2019url, engine='python', error_bad_lines=False)
NBA_02_2019df=pd.DataFrame(NBA_02_2019)
NBA_03_2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_03_2019.csv'
NBA_03_2019=pd.read_csv(NBA_03_2019url, engine='python', error_bad_lines=False)
NBA_03_2019df=pd.DataFrame(NBA_03_2019)
NBA_04_2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_04_2019.csv'
NBA_04_2019=pd.read_csv(NBA_04_2019url, engine='python', error_bad_lines=False)
NBA_04_2019df=pd.DataFrame(NBA_04_2019)
NBA_05_2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_05_2019.csv'
NBA_05_2019=pd.read_csv(NBA_05_2019url, engine='python', error_bad_lines=False)
NBA_05_2019df=pd.DataFrame(NBA_05_2019)
NBA_06_2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_06_2019.csv'
NBA_06_2019=pd.read_csv(NBA_06_2019url, engine='python', error_bad_lines=False)
NBA_06_2019df=pd.DataFrame(NBA_06_2019)
NBA_10_2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_10_2019.csv'
NBA_10_2019=pd.read_csv(NBA_10_2019url, engine='python', error_bad_lines=False)
NBA_10_2019df=pd.DataFrame(NBA_10_2019)
NBA_11_2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_11_2019.csv'
NBA_11_2019=pd.read_csv(NBA_11_2019url, engine='python', error_bad_lines=False)
NBA_11_2019df=pd.DataFrame(NBA_11_2019)
NBA_12_2019url='https://raw.githubusercontent.com/holden-herrell/IST718_GROUP_PROJECT/master/DATASETS/NBA%20DATA/NBA_12_2019.csv'
NBA_12_2019=pd.read_csv(NBA_12_2019url, engine='python', error_bad_lines=False)
NBA_12_2019df=pd.DataFrame(NBA_12_2019)

# %%
#Combine NBA Schedule Data
NBASchedule=NBA_01_2017df.append(NBA_02_2017df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_03_2017df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_04_2017df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_05_2017df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_06_2017df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_10_2017df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_11_2017df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_12_2017df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_01_2018df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_02_2018df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_03_2018df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_04_2018df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_05_2018df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_06_2018df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_10_2018df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_11_2018df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_12_2018df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_01_2019df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_02_2019df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_03_2019df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_04_2019df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_05_2019df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_06_2019df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_10_2019df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_11_2019df, sort=False, ignore_index=True)
NBASchedule=NBASchedule.append(NBA_12_2019df, sort=False, ignore_index=True)
pd.options.display.max_rows = 9999
print(NBASchedule)
# Out:
#                  Date Start (ET)         Visitor/Neutral  PTS  \
# 0      Sun Jan 1 2017      6:00p       San Antonio Spurs  112
# 1      Sun Jan 1 2017      6:00p           Orlando Magic  104
# 2      Sun Jan 1 2017      6:00p         Detroit Pistons  107
# 3      Sun Jan 1 2017      7:00p  Portland Trail Blazers   95
# 4      Sun Jan 1 2017      9:30p         Toronto Raptors  123
# 5      Mon Jan 2 2017      7:00p    New Orleans Pelicans   82
# 6      Mon Jan 2 2017      7:00p   Oklahoma City Thunder   94
# 7      Mon Jan 2 2017      7:30p               Utah Jazz  101
# 8      Mon Jan 2 2017      7:30p           Orlando Magic  115
# 9      Mon Jan 2 2017      8:00p       Charlotte Hornets  111
# 10     Mon Jan 2 2017      8:00p      Washington Wizards   91
# 11     Mon Jan 2 2017     10:30p          Denver Nuggets  119
# 12     Mon Jan 2 2017     10:30p            Phoenix Suns   98
# 13     Tue Jan 3 2017      7:00p  Minnesota Timberwolves   91
# ...

# %%
#Rename columns
NBASchedule.rename(columns={"Home/Neutral":"HomeTeam","Unnamed: 7":"OT","Unnamed: 6":"BoxScore"},inplace=True)
print(NBASchedule)
# Out:
#                  Date Start (ET)         Visitor/Neutral  PTS  \
# 0      Sun Jan 1 2017      6:00p       San Antonio Spurs  112
# 1      Sun Jan 1 2017      6:00p           Orlando Magic  104
# 2      Sun Jan 1 2017      6:00p         Detroit Pistons  107
# 3      Sun Jan 1 2017      7:00p  Portland Trail Blazers   95
# 4      Sun Jan 1 2017      9:30p         Toronto Raptors  123
# 5      Mon Jan 2 2017      7:00p    New Orleans Pelicans   82
# 6      Mon Jan 2 2017      7:00p   Oklahoma City Thunder   94
# 7      Mon Jan 2 2017      7:30p               Utah Jazz  101
# 8      Mon Jan 2 2017      7:30p           Orlando Magic  115
# 9      Mon Jan 2 2017      8:00p       Charlotte Hornets  111
# 10     Mon Jan 2 2017      8:00p      Washington Wizards   91
# 11     Mon Jan 2 2017     10:30p          Denver Nuggets  119
# 12     Mon Jan 2 2017     10:30p            Phoenix Suns   98
# 13     Tue Jan 3 2017      7:00p  Minnesota Timberwolves   91
# ...

# %%
#Drop Unneeded columns
NBA=NBASchedule.drop(columns=['Visitor/Neutral','PTS','OT','BoxScore','Notes','PTS.1'])
print(NBA)
# Out:
#                  Date Start (ET)                HomeTeam  Attend.
# 0      Sun Jan 1 2017      6:00p           Atlanta Hawks  18088.0
# 1      Sun Jan 1 2017      6:00p          Indiana Pacers  17530.0
# 2      Sun Jan 1 2017      6:00p              Miami Heat  19844.0
# 3      Sun Jan 1 2017      7:00p  Minnesota Timberwolves  15804.0
# 4      Sun Jan 1 2017      9:30p      Los Angeles Lakers  18997.0
# 5      Mon Jan 2 2017      7:00p     Cleveland Cavaliers  20562.0
# 6      Mon Jan 2 2017      7:00p         Milwaukee Bucks  17423.0
# 7      Mon Jan 2 2017      7:30p           Brooklyn Nets  15634.0
# 8      Mon Jan 2 2017      7:30p         New York Knicks  19812.0
# 9      Mon Jan 2 2017      8:00p           Chicago Bulls  21612.0
# 10     Mon Jan 2 2017      8:00p         Houston Rockets  16569.0
# 11     Mon Jan 2 2017     10:30p   Golden State Warriors  19596.0
# 12     Mon Jan 2 2017     10:30p    Los Angeles Clippers  19060.0
# ...

# %%
#Subset for cities in this study
NBA= NBA[NBA['HomeTeam'].isin(['Atlanta Hawks','Dallas Mavericks','Houston Rockets','Miami Heat'])]
print(NBA)
# Out:
#                  Date Start (ET)          HomeTeam  Attend.
# 0      Sun Jan 1 2017      6:00p     Atlanta Hawks  18088.0
# 2      Sun Jan 1 2017      6:00p        Miami Heat  19844.0
# 10     Mon Jan 2 2017      8:00p   Houston Rockets  16569.0
# 16     Tue Jan 3 2017      8:30p  Dallas Mavericks  19318.0
# 31     Thu Jan 5 2017      8:00p   Houston Rockets  18055.0
# 33     Thu Jan 5 2017      8:30p  Dallas Mavericks  19570.0
# 49     Sat Jan 7 2017      8:30p  Dallas Mavericks  19655.0
# 66    Tue Jan 10 2017      8:00p   Houston Rockets  16196.0
# 86    Fri Jan 13 2017      8:00p     Atlanta Hawks  18216.0
# 87    Fri Jan 13 2017      8:00p   Houston Rockets  18055.0
# 98    Sun Jan 15 2017      2:00p  Dallas Mavericks  19655.0
# 99    Sun Jan 15 2017      3:00p     Atlanta Hawks  14231.0
# 115   Tue Jan 17 2017      7:30p        Miami Heat  19600.0
# 124   Wed Jan 18 2017      8:00p   Houston Rockets  15782.0
# 129   Thu Jan 19 2017      7:30p        Miami Heat  19600.0
# ...

# %%
#NBA.to_csv('NBA.csv', index=False)
